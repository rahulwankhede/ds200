# %% [markdown]
# # Plotter

# %% [markdown]
# ## 1. Bar plot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/Road_Accidents_2017-Tables_2.5.csv')
df
# Out:
#     Year  Number of Accidents - Total  Number of Accidents - Fatal  \
# 0   2005                       439255                        83491
# 1   2006                       460920                        93917
# 2   2007                       479216                       101161
# 3   2008                       484704                       106591
# 4   2009                       486384                       110993
# 5   2010                       499628                       119558
# 6   2011                       497686                       121618
# 7   2012                       490383                       123093
# 8   2013                       486476                       122589
# 9   2014                       489400                       125828
# 10  2015                       501423                       131726
# 11  2016                       480652                       136071
# 12  2017                       464910                       134796
#
# ...

# %%
plt.bar(df['Year'], df['Number of Accidents - Total'])
# Out:
# <BarContainer object of 13 artists>

# %% [markdown]
# ## 2. Box and Whiskers plot

# %%
df = pd.read_csv('data/1.12_Trend_of_Production_of_Motor_Vehicles_in_India_1961_1979.csv')
df
# Out:
#     Year  Jeeps   Cars  Commercial Vehicles  Two Wheelers - Motor Cycles  \
# 0   1961   7502  21662                25713                         8636
# 1   1962   7597  23326                26893                         8828
# 2   1963   8104  15711                28480                         9456
# 3   1964  10391  23227                33516                        13858
# 4   1965  10488  24790                37401                        21364
# 5   1966   9777  27597                35155                        25040
# 6   1967   5561  33395                31452                        23338
# 7   1968   7298  37308                35119                        29411
# 8   1969   7838  35183                35489                        34477
# 9   1970   9334  35305                41324                        43038
# 10  1971  11053  38316                42024                        39670
# 11  1972  12510  38827                38929                        47573
# ...

# %%
df.values
# Out:
# array([[  1961,   7502,  21662,  25713,   8636,  12817,   2634,  24087,
#           1267],
#        [  1962,   7597,  23326,  26893,   8828,  14318,    513,  23659,
#           1426],
#        [  1963,   8104,  15711,  28480,   9456,  15419,      5,  24880,
#           1701],
#        [  1964,  10391,  23227,  33516,  13858,  20043,   1445,  35346,
#           2493],
#        [  1965,  10488,  24790,  37401,  21364,  20316,   7444,  49124,
#           1884],
#        [  1966,   9777,  27597,  35155,  25040,  20971,   5591,  51602,
#           1255],
#        [  1967,   5561,  33395,  31452,  23338,  30302,   9108,  62748,
#           3995],
#        [  1968,   7298,  37308,  35119,  29411,  35942,   9553,  74906,
#           4317],
#        [  1969,   7838,  35183,  35489,  34477,  49740,  11043,  95260,
#           5072],
#        [  1970,   9334,  35305,  41324,  43038,  58442,  11691, 113171,
#           4229],
# ...

# %%
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f03f614c080>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f03f614c630>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f03f6138dd8>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f03f614cbe0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f03f614ceb8>,
# ...
#  'means': []}

# %% [markdown]
# ## 3. Scatter plot

# %% [markdown]
# #### Note: I could not find a dataset that would be apt for a scatter plot so I'm genarating my own data randomly and plotting it

# %%
np.random.seed(42)

# %%
n = 50

# %%
x = np.random.uniform(0,10,n)

# %%
y = 0.8 * x + 0.3 + np.random.normal(0,1,n)

# %%
plt.scatter(x,y)
